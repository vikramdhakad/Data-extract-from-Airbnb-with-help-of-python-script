# %% [markdown]
# # Import Required Requests

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from time import sleep
from webdriver_manager.chrome import ChromeDriverManager
import requests

# %% [markdown]
# # Setup the Selenium webdriver with chrome browser

# %%
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)

# Load the webpage on Chrome Browser

driver.get('https://www.airbnb.co.in/s/Goa--India/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Goa%2C%20India&place_id=ChIJQbc2YxC6vzsRkkDzYv-H-Oo&date_picker_type=calendar&checkin=2024-01-30&checkout=2024-01-31&source=structured_search_input_header&search_type=autocomplete_click')
sleep(5)
driver.maximize_window()

# %% [markdown]
# # Data Scraping and images scraping

# %%
for j in range(10):


    Title = []
    Rates = []

    for i in range(1,19):
        link = driver.find_element(By.XPATH,'//*[@id="site-content"]/div/div[2]/div/div/div/div/div[1]/div[{}]/div/div[2]/div/div/div/div/a'.format(i))
        driver.execute_script("arguments[0].click();", link)
        driver.switch_to.window(driver.window_handles[1])
        sleep(6)
        try:
            name = driver.find_element(By.XPATH,'//h1[@class="hpipapi atm_7l_1kw7nm4 atm_c8_1x4eueo atm_cs_1kw7nm4 atm_g3_1kw7nm4 atm_gi_idpfg4 atm_l8_idpfg4 atm_kd_idpfg4_pfnrn2 dir dir-ltr"]')
            Title.append(name.text)
        except:
            Title = " "
        
        try:
            rate = driver.find_element(By.XPATH,'//*[@id="site-content"]/div/div[1]/div[3]/div/div[2]/div/div/div[1]/div/div/div/div/div/div/div/div[1]/div[1]/div/div/span/div/span[1]')
            Rates.append(rate.text)
        except:
            Rates = " "
        
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        
    next_page = driver.find_element(By.XPATH,'//a[@class="l1ovpqvx atm_1y33qqm_1ggndnn_10saat9 atm_17zvjtw_zk357r_10saat9 atm_w3cb4q_il40rs_10saat9 c1ytbx3a atm_mk_h2mmj6 atm_9s_1txwivl atm_h_1h6ojuz atm_fc_1h6ojuz atm_bb_idpfg4 atm_26_1j28jx2 atm_3f_glywfm atm_7l_18pqv07 atm_gi_idpfg4 atm_l8_idpfg4 atm_uc_1dtz4sb atm_kd_glywfm atm_gz_xvenqj atm_uc_glywfm__p88qr9 atm_26_1nh1gcj_1rqz0hn_uv4tnr atm_tr_kv3y6q_csw3t1 atm_26_1nh1gcj_1ul2smo atm_3f_glywfm_jo46a5 atm_l8_idpfg4_jo46a5 atm_gi_idpfg4_jo46a5 atm_3f_glywfm_1icshfk atm_kd_glywfm_19774hq atm_70_glywfm_1w3cfyq atm_uc_x37zl0_9xuho3 atm_70_216vci_9xuho3 atm_26_1nh1gcj_9xuho3 atm_uc_glywfm_9xuho3_p88qr9 atm_70_glywfm_18zk5v0 atm_uc_x37zl0_fiqcvf atm_70_216vci_fiqcvf atm_26_1nh1gcj_fiqcvf atm_uc_glywfm_fiqcvf_p88qr9 atm_7l_161hw1_1o5j5ji atm_9j_13gfvf7_1o5j5ji atm_26_1j28jx2_154oz7f atm_92_1yyfdc7_vmtskl atm_9s_1ulexfb_vmtskl atm_mk_stnw88_vmtskl atm_tk_1ssbidh_vmtskl atm_fq_1ssbidh_vmtskl atm_tr_pryxvc_vmtskl atm_vy_1vi7ecw_vmtskl atm_e2_1vi7ecw_vmtskl atm_5j_1ssbidh_vmtskl atm_mk_h2mmj6_1ko0jae dir dir-ltr"]')
    next_page.click()
    sleep(2)

# %%
data = pd.DataFrame()
data['Titles'] = Title
data['Room Rate'] = Rates

data
# Out:
#                                           Titles Room Rate
# 0               Entire apartment in Marna, India   ₹3,202
# 1              Entire apartment in Siolim, India   ₹5,222
# 2              Entire home in Verla Canca, India   ₹2,500
# 3             Entire rental unit in Marra, India   ₹4,199
# 4              Entire rental unit in Baga, India   ₹4,599
# 5            Entire apartment in Candolim, India  ₹12,000
# 6                  Entire home in Assagao, India   ₹4,500
# 7          Entire rental unit in Candolim, India   ₹2,469
# 8            Entire rental unit in Arpora, India   ₹7,009
# 9   Entire serviced apartment in Candolim, India   ₹4,246
# 10           Entire rental unit in Arpora, India   ₹6,999
# 11           Entire rental unit in Siolim, India   ₹2,500
# 12           Entire rental unit in Arpora, India   ₹3,300
# 13           Entire rental unit in Arpora, India   ₹4,300
# 14                 Entire villa in Siolim, India  ₹17,777
# ...

# %%
data.to_csv('Airbnb_data.csv')

# %%
driver.quit()
